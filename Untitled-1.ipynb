# %%
import matplotlib.pyplot as plt

with open('screenlog.0') as f:
    data = list(map(lambda x: int(x), f.readlines()))
    plt.plot(data)

# %%
means = []
for i in range(0, len(data), 10):
    means.append(sum(data[i:i+10])/10)
    
plt.plot(means)
